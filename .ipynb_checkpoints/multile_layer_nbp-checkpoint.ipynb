# %%
##### import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
delta=5
def gausin_distance(x,y,delta=delta):
    H= torch.norm(x-y).cuda()
    distance = torch.exp(-H/2/(delta**2)).cuda()
    
    return distance
def gram_matrix(data,kernel=gausin_distance):
    #num=data.shape[0]
    #matrix=torch.zeros((num,num)).cuda()
    #for i in range (0,num):
    #   for j in range (0,num):
    #        matrix[i][j]=kernel(data[i],data[j])
    num=data.shape[0]
    datav3=torch.mm(data,torch.transpose(data, 0, 1).cuda()).cuda()
    datav1=torch.diag(datav3,0).cuda()
    #print(datav1.shape)
    #matrix=torch.sqrt(datav1+datav2-2*datav3)
    buf1=((-2)*datav3+datav1).cuda()
    buf2=torch.transpose(buf1, 0, 1).cuda()
    buf3=(buf2+datav1).cuda()
    #print(buf3)
    matrix = torch.exp(-buf3/2/(delta**2)).cuda()
    return matrix
def emerinal_hsic(X,Y):
    num=X.shape[0]
    #print(num)
    
    
    
    Kx=gram_matrix(X)
    
    Ky=gram_matrix(Y)
    
    H = torch.eye(num).cuda() - torch.ones((num,num), dtype = torch.float32).cuda() / num
    #print(H)
    hsic=1/(num-1)*torch.trace(torch.mm(torch.mm(torch.mm(Kx,H).cuda(),Ky).cuda(),H).cuda()).cuda()
    
    return hsic
import torch
import torchvision
from torchvision import transforms
import torch.nn.functional as F
import torchvision.datasets
from PIL import Image
batch_size=256
class MyMNIST(torchvision.datasets.MNIST):
    def __init__(self, root, train=True, transform=None, target_transform=None,download=False):
        
        super(MyMNIST,self).__init__(root, train, transform, target_transform,download)
        #print(self.data)
    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is index of the target class.
        """
        img, target = self.data[index], int(self.targets[index])
        #print(target) 
        # doing this so that it is consistent with all other datasets
        # to return a PIL Image
        img = Image.fromarray(img.numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = self.target_transform(target)
            
        else:
            target=torch.as_tensor(target)
            target = F.one_hot(target,num_classes=10).cuda()

        return img, target
mnist_data=torchvision.datasets.MNIST(root='./MNIST/', train=True, transform=transforms.ToTensor(), target_transform=None, download=False)
data_loader = torch.utils.data.DataLoader(mnist_data,
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=2)
#D_in, H1,H2,H3,H4,H5,H6,H7, D_out = 784, 64,32,16,8,4,2,1,10
layer_num=[784,64,32,16,4,1]
costs=[]
dtype=torch.float
continue_flag=1
PATH='./checkpoint_multilayer_nbp'
w=[]
z=[]
b=[]
rate_list=[]
if continue_flag:
    
    checkpoint = torch.load(PATH)
    
    w=checkpoint['w']
    b=checkpoint['b']

else:
    for i in range(len(layer_num)-1):
    
        w.append(torch.randn(layer_num[i],layer_num[i+1], dtype=dtype, requires_grad=True,device="cuda"))
        b.append(torch.randn(layer_num[i+1],dtype=dtype, requires_grad=True,device="cuda"))
epoches=50
lamda=200
learning_rate=0.01
data_tsne_label=[]
data_tsne_rp1=[]
data_tsne_rp2=[]
for i in range(epoches): 
    for i_batch, (img,target) in enumerate(data_loader):
        costs=[]
        z=[]
        img=img.reshape(-1,layer_num[0]).cuda()
        
        target=torch.as_tensor(target).cuda()
        num=target.shape[0]
        #print(num)
        target=target.reshape(num,1).cuda()
        #target = F.one_hot(target,num_classes=10).cuda()
        target=torch.zeros((num,10)).cuda().scatter_(1,target,1).cuda()
        
        target=torch.as_tensor(target,dtype=dtype).cuda()
        
        z.append(torch.tanh(torch.mm(img,w[0]).cuda()+b[0]).cuda())
        for cnt in range(len(w)-1):
            
            z.append(torch.tanh(torch.mm(z[cnt],w[cnt+1]).cuda()+b[cnt+1].cuda()).cuda())
            
        grad_listw=[]
        grad_listb=[]
        lock=[0,1,2,3,4,5]
        for cnt in range(len(z)-1):
            
            entropy=emerinal_hsic(z[cnt],img)
                
            
            information=lamda*emerinal_hsic(z[cnt],target)
            cost=-entropy
            #-information
            costs.append(cost)
            #0.1*(entropy/information)
        #print(cost1)
            cost.backward(retain_graph=True)
            #print('!')
        #print(w1.cuda().grad)
            with torch.no_grad():
                bufw=torch.zeros((w[cnt].shape)).cuda()
                bufb=torch.zeros((b[cnt].shape)).cuda()
                #print(buf.shape)
                bufw.copy_(w[cnt].grad)
                bufb.copy_(b[cnt].grad)
                grad_listw.append(bufw)
                grad_listb.append(bufb)
            #print('grad1',torch.norm(grad1))
            #w2 -= learning_rate * w2.grad

            # Manually zero the gradients after updating weights
                w[cnt].grad.zero_()
                b[cnt].grad.zero_()
                #print(cnt,torch.norm(buf))
            #w2.grad.zero_()
        entropy=emerinal_hsic(z[-1],img)
        information=lamda*emerinal_hsic(z[-1],target)
        rate=emerinal_hsic(z[-1],img)/information
        cost=-entropy
        #-information
        costs.append(cost)
        #+rate
        #+0.1*(entropy/information)
        cost.backward()
        with torch.no_grad():
            #w1 -= learning_rate * w1.grad
            #print('grad2',torch.norm(w2.grad))
            w[-1] -= learning_rate * w[-1].grad
            b[-1] -= learning_rate * b[-1].grad
            
            for cnt in range(len(w)-1):
                w[cnt] -= learning_rate * grad_listw[cnt]
                b[cnt] -= learning_rate * grad_listb[cnt]
        # Manually zero the gradients after updating weights
            w[-1].grad.zero_()
            b[-1].grad.zero_()
        #    data_tsne_rp2.append(z2.cpu().data.numpy())
        #    data_tsne_rp1.append(z1.cpu().data.numpy())
        #    data_tsne_label.append(target.argmax(dim=1, keepdim=True).cpu().data.numpy())
        

        if i_batch %100 ==0:
            print(rate)
            rate_list.append(rate)
            print(i_batch)
            print('costs',costs)
            print('entr',entropy)
            print('inf',information)
            data_tsne_label.append(target.argmax(dim=1, keepdim=True).cpu().data.numpy())
            torch.save({
            'w': w,
            'z': z,
            'b': b,
            'data_tsne_label':target.argmax(dim=1, keepdim=True).cpu().data.numpy()
            ,'costs':costs
            #'data_tsne_rp2':data_tsne_rp2,
            #'data_tsne_rp1':data_tsne_rp1
                
            }, PATH)
            
            data_tsne_label=[]
            #data_tsne_rp1=[]
            #data_tsne_rp2=[]

            #for j,zz in enumerate(z2):
                #print(j,zz)
                #print(j,target[j])
            
plt.plot(rate_list)
plt.ylabel('rate')
plt.xlabel('epochs (per 1)')
plt.title("Learning rate = " + str(learning_rate))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# tensor(0.0252, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.7576, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6827, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0278, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6891, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1741, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1741, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.9073, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0254, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.7359, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.7517, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0581, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7074, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1790, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1790, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(7.0538, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.6238, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6655, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0485, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7165, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1897, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1897, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.8815, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0252, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.4366, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.4296, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.7643, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6237, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1632, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1632, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.4753, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0272, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.6506, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6071, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9043, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6400, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1681, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1681, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.1810, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0261, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.4333, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.4344, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.7887, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6383, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1667, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1667, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.3822, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0281, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.9337, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.8707, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1432, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7387, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1955, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1955, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.9596, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0264, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.7911, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.7794, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0693, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7139, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1894, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1894, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(7.1718, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-3.4042, device='cuda:0', grad_fn=<NegBackward>), tensor(-3.2999, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.4749, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.8524, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.2215, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.2215, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(7.2563, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.7442, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6941, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9794, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6784, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1766, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1766, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.3947, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0256, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.9623, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.8877, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1381, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7162, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1761, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1761, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.8698, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.7704, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.7270, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0981, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7282, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1876, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1876, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.8012, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0263, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.7373, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6960, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9869, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6729, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1792, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1792, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.8111, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0280, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.6851, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6981, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1074, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7383, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1982, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1982, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(7.0859, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0255, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.5858, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6011, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9892, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6983, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1853, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1853, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(7.2544, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0284, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.7606, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.7694, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0991, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7242, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1884, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1884, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.6398, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0256, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.6062, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.5612, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.8257, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6241, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1499, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1499, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(5.8628, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0246, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.5816, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.5653, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9363, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6697, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1728, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1728, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(7.0389, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0246, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.4669, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.4542, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.8522, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6580, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1766, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1766, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(7.1912, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0291, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.6901, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6264, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9765, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6827, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1748, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1748, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.0071, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0258, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.8259, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.7533, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0036, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6775, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1750, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1750, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.7946, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0273, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.6797, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6499, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9995, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6907, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1827, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1827, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.6798, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0258, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.5720, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.5881, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9581, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6817, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1787, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1787, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.9258, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0307, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-3.0181, device='cuda:0', grad_fn=<NegBackward>), tensor(-3.0107, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.2602, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7748, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.2093, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.2093, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.8094, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0275, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.8901, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.8427, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1298, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7227, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1852, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1852, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.7437, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0273, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-3.0634, device='cuda:0', grad_fn=<NegBackward>), tensor(-3.0099, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.2351, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7472, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1820, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1820, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.6579, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0231, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.4080, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.3895, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.7827, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6164, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1552, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1552, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.7098, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0273, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.7422, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.7538, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0956, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7276, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1954, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1954, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(7.1645, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0251, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.9535, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.8836, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1838, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7392, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1791, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1791, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(7.1434, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0282, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.6805, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6692, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0023, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6992, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1824, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1824, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.4660, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0311, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.9782, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.8488, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1017, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7012, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1718, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1718, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(5.5155, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0266, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.6596, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6081, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9558, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6666, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1734, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1734, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.5205, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0275, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.8473, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.8162, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1357, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7272, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1850, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1850, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.7148, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0296, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-3.0020, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.9166, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1756, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7384, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1878, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1878, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.3414, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0270, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.6987, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6676, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9950, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6926, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1778, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1778, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.5964, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0286, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.6034, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6708, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0393, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7281, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1981, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1981, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.9291, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0283, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2
device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6444, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1615, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1615, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.3840, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0296, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.7160, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6510, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0483, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7077, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1878, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1878, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.3468, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0346, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.6277, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6541, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0202, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6980, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1849, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1849, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(5.3435, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0298, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.9830, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.9277, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.2060, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7415, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1843, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1843, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.1935, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0279, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.6800, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.6247, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9885, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6859, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1783, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1783, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.3828, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0315, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-3.3861, device='cuda:0', grad_fn=<NegBackward>), tensor(-3.2839, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.4427, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.8343, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.2158, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.2158, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.8508, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0271, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.5401, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.5630, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9829, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6916, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1879, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1879, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.9432, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0287, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-3.1050, device='cuda:0', grad_fn=<NegBackward>), tensor(-3.0187, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.2685, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7518, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1780, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1780, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.1931, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0315, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-3.0410, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.9659, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.2981, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7774, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.2005, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.2005, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.3667, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0295, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.7775, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.7965, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1740, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7654, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.2038, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.2038, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.9159, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0280, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.8408, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.7573, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1090, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7074, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1723, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1723, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.1622, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0387, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.6268, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.5727, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9912, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6961, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1908, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1908, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(4.9251, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0325, device='cuda:0', grad_fn=<DivBackward0>)
# 0
# costs [tensor(-2.5125, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.5158, device='cuda:0', grad_fn=<NegBackward>), tensor(-1.9138, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.6708, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1788, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1788, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(5.4957, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0306, device='cuda:0', grad_fn=<DivBackward0>)
# 100
# costs [tensor(-2.9168, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.8882, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.1902, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7534, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1963, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1963, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(6.4199, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.0303, device='cuda:0', grad_fn=<DivBackward0>)
# 200
# costs [tensor(-2.7162, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.7326, device='cuda:0', grad_fn=<NegBackward>), tensor(-2.0877, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.7033, device='cuda:0', grad_fn=<NegBackward>), tensor(-0.1746, device='cuda:0', grad_fn=<NegBackward>)]
# entr tensor(0.1746, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(5.7586, device='cuda:0', grad_fn=<MulBackward0>)

# %%
##### import torch
import matplotlib.pyplot as plt
from matplotlib import cm
# %pylab inline
import numpy as np
try: from sklearn.manifold import TSNE; HAS_SK = True
except: HAS_SK = False; print('Please install sklearn for layer visualization')
def plot_with_labels(lowDWeights, labels):
    plt.cla()
    X, Y = lowDWeights[:, 0], lowDWeights[:, 1]
    print(len(labels))
    for x, y, s in zip(X, Y, labels):
        c = cm.rainbow(int(255 * s / 9)); plt.text(x, y, s, backgroundcolor=c, fontsize=9)
    plt.xlim(X.min(), X.max()); plt.ylim(Y.min(), Y.max()); plt.title('Visualize last layer'); plt.show(); plt.pause(0.01)

plt.ion()
PATH='./checkpoint_multilayer_nbp'
checkpoint = torch.load(PATH)
data_tsne_label=np.array(checkpoint['data_tsne_label'])
data_tsne_rp=np.array(checkpoint['z'][-1].cpu().data.numpy())
print(data_tsne_rp.shape)
print(data_tsne_rp[:50,:],data_tsne_label[:50])
for j in range(500):
    if data_tsne_label[j]==2:
        
        print(data_tsne_rp[j,:])
    
#print()
data_tsne_label=data_tsne_label.reshape((-1))
#print(data_tsne_label)
#data_tsne=np.array(data_tsne[:][])
if HAS_SK:
    # Visualization of trained flatten layer (T-SNE)
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=500)
    plot_only = 255
    low_dim_embs = tsne.fit_transform(data_tsne_rp[:plot_only,:])
    labels = data_tsne_label[:plot_only]
    plot_with_labels(low_dim_embs, labels)
plt.ioff()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (256, 1)
# [[ 0.46471953]
#  [-0.82766646]
#  [ 0.9702898 ]
#  [-0.9619364 ]
#  [ 0.934251  ]
#  [ 0.99547   ]
#  [ 0.72801495]
#  [ 0.9924328 ]
#  [-0.8758619 ]
#  [ 0.9985784 ]
#  [-0.955257  ]
#  [ 0.9988217 ]
#  [ 0.47639382]
#  [ 0.96668047]
#  [-0.30634132]
#  [-0.95631194]
#  [ 0.03375993]
#  [ 0.99917275]
#  [ 0.9814563 ]
#  [ 0.241264  ]
#  [ 0.96755624]
#  [ 0.99953455]
#  [-0.32395768]
#  [ 0.3800482 ]
#  [ 0.99020684]
#  [ 0.9755282 ]
#  [ 0.5734639 ]
#  [ 0.32575873]
#  [ 0.72667235]
#  [ 0.36507142]
#  [ 0.9905651 ]
#  [ 0.99904627]
#  [-0.88192326]
#  [-0.9638077 ]
#  [ 0.8115372 ]
#  [-0.47408763]
#  [-0.91842645]
#  [-0.7926794 ]
#  [-0.759114  ]
#  [ 0.38156316]
#  [ 0.3460139 ]
#  [-0.02555315]
#  [-0.79634815]
#  [ 0.3418505 ]
#  [-0.8629987 ]
#  [-0.95730644]
#  [ 0.9987033 ]
#  [-0.821211  ]
#  [-0.40971687]
#  [ 0.3562263 ]] [[0]
#  [8]
#  [7]
#  [1]
#  [2]
#  [4]
#  [2]
#  [0]
#  [2]
#  [9]
#  [1]
#  [6]
#  [6]
#  [7]
#  [3]
#  [9]
#  [0]
#  [9]
#  [9]
#  [4]
#  [3]
#  [3]
#  [7]
#  [2]
#  [7]
#  [8]
#  [9]
#  [0]
#  [2]
#  [0]
#  [9]
#  [4]
#  [8]
#  [7]
#  [9]
#  [6]
#  [8]
#  [7]
#  [8]
#  [2]
#  [2]
#  [6]
#  [4]
#  [1]
#  [0]
#  [9]
#  [0]
#  [2]
#  [5]
#  [1]]
# [0.934251]
# [0.72801495]
# [-0.8758619]
# [0.3800482]
# [0.72667235]
# [0.38156316]
# [0.3460139]
# [-0.821211]
# [-0.8942334]
# [0.2524745]
# [0.30490404]
# [-0.8637616]
# [-0.9440906]
# [-0.9681716]
# [0.65626264]
# [-0.3337337]
# [-0.01186279]
# [0.3223377]
# [0.8134972]
# [-0.83239096]
# [0.99869865]
# [0.42408815]
# [0.4204215]
# [-0.23502572]
# [0.4621477]
# [-0.07554606]
# [-0.85891056]
# /usr/local/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['rate', 'entropy', 'dtype']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-ee5489a60426> in <module>
#      22 print(data_tsne_rp[:50,:],data_tsne_label[:50])
#      23 for j in range(500):
# ---> 24     if data_tsne_label[j]==2:
#      25
#      26         print(data_tsne_rp[j,:])
#
# IndexError: index 256 is out of bounds for axis 0 with size 256
