# %%
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
delta=5
def gausin_distance(x,y,delta=delta):
    H= torch.norm(x-y).cuda()
    distance = torch.exp(-H/2/(delta**2)).cuda()
    
    return distance
def gram_matrix(data,kernel=gausin_distance):
    #num=data.shape[0]
    #matrix=torch.zeros((num,num)).cuda()
    #for i in range (0,num):
    #   for j in range (0,num):
    #        matrix[i][j]=kernel(data[i],data[j])
    num=data.shape[0]
    datav3=torch.mm(data,torch.transpose(data, 0, 1).cuda()).cuda()
    datav1=torch.diag(datav3,0).cuda()
    #print(datav1.shape)
    #matrix=torch.sqrt(datav1+datav2-2*datav3)
    buf1=((-2)*datav3+datav1).cuda()
    buf2=torch.transpose(buf1, 0, 1).cuda()
    buf3=(buf2+datav1).cuda()
    #print(buf3)
    matrix = torch.exp(-buf3/2/(delta**2)).cuda()
    return matrix
def emerinal_hsic(X,Y):
    num=X.shape[0]
    #print(num)
    
    
    
    Kx=gram_matrix(X)
    
    Ky=gram_matrix(Y)
    
    H = torch.eye(num).cuda() - torch.ones((num,num), dtype = torch.float32).cuda() / num
    #print(H)
    hsic=1/(num-1)*torch.trace(torch.mm(torch.mm(torch.mm(Kx,H).cuda(),Ky).cuda(),H).cuda()).cuda()
    
    return hsic
import torch
import torchvision
from torchvision import transforms
import torch.nn.functional as F
import torchvision.datasets
from PIL import Image
batch_size=256
class MyMNIST(torchvision.datasets.MNIST):
    def __init__(self, root, train=True, transform=None, target_transform=None,download=False):
        
        super(MyMNIST,self).__init__(root, train, transform, target_transform,download)
        #print(self.data)
    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is index of the target class.
        """
        img, target = self.data[index], int(self.targets[index])
        #print(target) 
        # doing this so that it is consistent with all other datasets
        # to return a PIL Image
        img = Image.fromarray(img.numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = self.target_transform(target)
            
        else:
            target=torch.as_tensor(target)
            target = F.one_hot(target,num_classes=10).cuda()

        return img, target
mnist_data=torchvision.datasets.MNIST(root='./MNIST/', train=True, transform=transforms.ToTensor(), target_transform=None, download=False)
data_loader = torch.utils.data.DataLoader(mnist_data,
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=2)
#D_in, H1,H2,H3,H4,H5,H6,H7, D_out = 784, 64,32,16,8,4,2,1,10
layer_num=[784,64]
costs=[]
dtype=torch.float
continue_flag=1
PATH='./checkpoint_onelayer'
w=[]
z=[]

if continue_flag:
    
    checkpoint = torch.load(PATH)
    
    w=checkpoint['w']

else:
    for i in range(len(layer_num)-1):
    
        w.append(torch.randn(layer_num[i],layer_num[i+1], dtype=dtype, requires_grad=True,device="cuda"))

epoches=13
lamda=5
learning_rate=0.001
data_tsne_label=[]
data_tsne_rp1=[]
data_tsne_rp2=[]
for i in range(epoches): 
    for i_batch, (img,target) in enumerate(data_loader):
        z=[]
        img=img.reshape(-1,layer_num[0]).cuda()
        
        target=torch.as_tensor(target).cuda()
        num=target.shape[0]
        #print(num)
        target=target.reshape(num,1).cuda()
        #target = F.one_hot(target,num_classes=10).cuda()
        target=torch.zeros((num,10)).cuda().scatter_(1,target,1).cuda()
        
        target=torch.as_tensor(target,dtype=dtype).cuda()
        
        z.append(torch.tanh(torch.mm(img,w[0]).cuda()).cuda())
        for cnt in range(len(w)-1):
            
            z.append(torch.tanh(torch.mm(z[cnt],w[cnt+1]).cuda()).cuda())
            
        grad_list=[]
        
        for cnt in range(len(z)-1):

            
            cost=-emerinal_hsic(z[cnt],img)-lamda*emerinal_hsic(z[cnt],target)
        #print(cost1)
            cost.backward(retain_graph=True)
            print('!')
        #print(w1.cuda().grad)
            with torch.no_grad():
                buf=torch.zeros((w[cnt].shape)).cuda()
                #print(buf.shape)
                buf.copy_(w[cnt].grad)
                
                grad_list.append(buf)
            #print('grad1',torch.norm(grad1))
            #w2 -= learning_rate * w2.grad

            # Manually zero the gradients after updating weights
                w[cnt].grad.zero_()
                #print(cnt,torch.norm(buf))
            #w2.grad.zero_()
        entropy=emerinal_hsic(z[-1],img)
        information=lamda*emerinal_hsic(z[-1],target)
        cost=-entropy-information
        cost.backward()
        
        with torch.no_grad():
            #w1 -= learning_rate * w1.grad
            #print('grad2',torch.norm(w2.grad))
            w[-1] -= learning_rate * w[-1].grad
            
            for cnt in range(len(w)-1):
                w[cnt] -= learning_rate * grad_list[cnt]
        # Manually zero the gradients after updating weights
            w[-1].grad.zero_()
            
        #    data_tsne_rp2.append(z2.cpu().data.numpy())
        #    data_tsne_rp1.append(z1.cpu().data.numpy())
        #    data_tsne_label.append(target.argmax(dim=1, keepdim=True).cpu().data.numpy())
        

        if i_batch %100 ==0:
            costs.append(cost)
            print(i_batch)
            print('cost',cost)
            print('entr',entropy)
            print('inf',information)
            data_tsne_label.append(target.argmax(dim=1, keepdim=True).cpu().data.numpy())
            torch.save({
            'w': w,
            'z': z,
            'data_tsne_label':target.argmax(dim=1, keepdim=True).cpu().data.numpy()
            ,'costs':costs
            #'data_tsne_rp2':data_tsne_rp2,
            #'data_tsne_rp1':data_tsne_rp1
                
            }, PATH)
            
            data_tsne_label=[]
            #data_tsne_rp1=[]
            #data_tsne_rp2=[]

            #for j,zz in enumerate(z2):
                #print(j,zz)
                #print(j,target[j])
            
plt.plot(costs)
plt.ylabel('cost2')
plt.xlabel('epochs (per 1)')
plt.title("Learning rate = " + str(learning_rate))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 0
# cost tensor(-2.3433, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7413, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6020, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.3285, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7243, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6043, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.3890, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7843, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6047, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.1572, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6260, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5313, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.2477, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6587, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5890, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.2774, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6963, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5811, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.1485, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.5819, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5665, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.2649, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6955, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5694, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.3511, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7295, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6216, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.3485, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7484, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6001, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.3316, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7140, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6176, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.1963, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.5958, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6004, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.1018, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.5680, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5338, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.5896, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.8957, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6939, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.1557, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6052, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5505, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.0561, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.5573, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4988, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.8688, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(2.1050, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.7638, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.6223, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.9341, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6882, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.1571, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6132, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5439, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.2825, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6782, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6043, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-1.9075, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.4522, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4553, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.2428, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6629, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5799, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.3953, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.8011, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5941, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.3908, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7787, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6121, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.1457, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.5804, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5653, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.4777, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.8090, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6687, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.1686, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6200, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5485, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.5624, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.9062, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6562, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.5572, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.9072, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6500, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.3254, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7382, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5872, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.4735, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.8163, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6572, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.1996, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6323, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5673, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.5786, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.9133, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6653, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.1137, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.5715, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5422, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.3757, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7328, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6430, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.3700, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7693, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6006, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(-2.3789, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.7560, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.6229, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(-2.1823, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.6296, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5527, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(-2.0571, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.5366, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.5206, device='cuda:0', grad_fn=<MulBackward0>)

# %%
import torch
import matplotlib.pyplot as plt
from matplotlib import cm
# %pylab inline
import numpy as np
try: from sklearn.manifold import TSNE; HAS_SK = True
except: HAS_SK = False; print('Please install sklearn for layer visualization')
def plot_with_labels(lowDWeights, labels):
    plt.cla()
    X, Y = lowDWeights[:, 0], lowDWeights[:, 1]
    print(len(labels))
    for x, y, s in zip(X, Y, labels):
        c = cm.rainbow(int(255 * s / 9)); plt.text(x, y, s, backgroundcolor=c, fontsize=9)
    plt.xlim(X.min(), X.max()); plt.ylim(Y.min(), Y.max()); plt.title('Visualize last layer'); plt.show(); plt.pause(0.01)

plt.ion()
PATH='./checkpoint_onelayer'
checkpoint = torch.load(PATH)
data_tsne_label=np.array(checkpoint['data_tsne_label'])
data_tsne_rp=np.array(checkpoint['z'][0].cpu().data.numpy())
print(data_tsne_rp.shape)
data_tsne_label=data_tsne_label.reshape((-1))
#print(data_tsne_label)
#data_tsne=np.array(data_tsne[:][])
if HAS_SK:
    # Visualization of trained flatten layer (T-SNE)
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 255
    low_dim_embs = tsne.fit_transform(data_tsne_rp[:plot_only,:])
    labels = data_tsne_label[:plot_only]
    plot_with_labels(low_dim_embs, labels)
plt.ioff()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['dtype', 'entropy']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# (256, 64)
# 255

# %%
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
delta=5
def gausin_distance(x,y,delta=delta):
    H= torch.norm(x-y).cuda()
    distance = torch.exp(-H/2/(delta**2)).cuda()
    
    return distance
def gram_matrix(data,kernel=gausin_distance):
    #num=data.shape[0]
    #matrix=torch.zeros((num,num)).cuda()
    #for i in range (0,num):
    #   for j in range (0,num):
    #        matrix[i][j]=kernel(data[i],data[j])
    num=data.shape[0]
    datav3=torch.mm(data,torch.transpose(data, 0, 1).cuda()).cuda()
    datav1=torch.diag(datav3,0).cuda()
    #print(datav1.shape)
    #matrix=torch.sqrt(datav1+datav2-2*datav3)
    buf1=((-2)*datav3+datav1).cuda()
    buf2=torch.transpose(buf1, 0, 1).cuda()
    buf3=(buf2+datav1).cuda()
    #print(buf3)
    matrix = torch.exp(-buf3/2/(delta**2)).cuda()
    return matrix
def emerinal_hsic(X,Y):
    num=X.shape[0]
    #print(num)
    
    
    
    Kx=gram_matrix(X)
    
    Ky=gram_matrix(Y)
    
    H = torch.eye(num).cuda() - torch.ones((num,num), dtype = torch.float32).cuda() / num
    #print(H)
    hsic=1/(num-1)*torch.trace(torch.mm(torch.mm(torch.mm(Kx,H).cuda(),Ky).cuda(),H).cuda()).cuda()
    
    return hsic
import torch
import torchvision
from torchvision import transforms
import torch.nn.functional as F
import torchvision.datasets
from PIL import Image
batch_size=256
class MyMNIST(torchvision.datasets.MNIST):
    def __init__(self, root, train=True, transform=None, target_transform=None,download=False):
        
        super(MyMNIST,self).__init__(root, train, transform, target_transform,download)
        #print(self.data)
    def __getitem__(self, index):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is index of the target class.
        """
        img, target = self.data[index], int(self.targets[index])
        #print(target) 
        # doing this so that it is consistent with all other datasets
        # to return a PIL Image
        img = Image.fromarray(img.numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = self.target_transform(target)
            
        else:
            target=torch.as_tensor(target)
            target = F.one_hot(target,num_classes=10).cuda()

        return img, target
mnist_data=torchvision.datasets.MNIST(root='./MNIST/', train=True, transform=transforms.ToTensor(), target_transform=None, download=False)
data_loader = torch.utils.data.DataLoader(mnist_data,
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=2)
#D_in, H1,H2,H3,H4,H5,H6,H7, D_out = 784, 64,32,16,8,4,2,1,10
layer_num=[784,64]
costs=[]
dtype=torch.float
continue_flag=1
PATH='./checkpoint_onelayer_entrlowest'
w=[]
z=[]

if continue_flag:
    
    checkpoint = torch.load(PATH)
    
    w=checkpoint['w']

else:
    for i in range(len(layer_num)-1):
    
        w.append(torch.randn(layer_num[i],layer_num[i+1], dtype=dtype, requires_grad=True,device="cuda"))

epoches=13
lamda=5
learning_rate=0.01
data_tsne_label=[]
data_tsne_rp1=[]
data_tsne_rp2=[]
for i in range(epoches): 
    for i_batch, (img,target) in enumerate(data_loader):
        z=[]
        img=img.reshape(-1,layer_num[0]).cuda()
        
        target=torch.as_tensor(target).cuda()
        num=target.shape[0]
        #print(num)
        target=target.reshape(num,1).cuda()
        #target = F.one_hot(target,num_classes=10).cuda()
        target=torch.zeros((num,10)).cuda().scatter_(1,target,1).cuda()
        
        target=torch.as_tensor(target,dtype=dtype).cuda()
        
        z.append(torch.tanh(torch.mm(img,w[0]).cuda()).cuda())
        for cnt in range(len(w)-1):
            
            z.append(torch.tanh(torch.mm(z[cnt],w[cnt+1]).cuda()).cuda())
            
        grad_list=[]
        
        for cnt in range(len(z)-1):

            
            cost=-emerinal_hsic(z[cnt],img)-lamda*emerinal_hsic(z[cnt],target)
        #print(cost1)
            cost.backward(retain_graph=True)
            print('!')
        #print(w1.cuda().grad)
            with torch.no_grad():
                buf=torch.zeros((w[cnt].shape)).cuda()
                #print(buf.shape)
                buf.copy_(w[cnt].grad)
                
                grad_list.append(buf)
            #print('grad1',torch.norm(grad1))
            #w2 -= learning_rate * w2.grad

            # Manually zero the gradients after updating weights
                w[cnt].grad.zero_()
                #print(cnt,torch.norm(buf))
            #w2.grad.zero_()
        entropy=emerinal_hsic(z[-1],img)
        information=lamda*emerinal_hsic(z[-1],target)
        cost=entropy-information
        cost.backward()
        
        with torch.no_grad():
            #w1 -= learning_rate * w1.grad
            #print('grad2',torch.norm(w2.grad))
            w[-1] -= learning_rate * w[-1].grad
            
            for cnt in range(len(w)-1):
                w[cnt] -= learning_rate * grad_list[cnt]
        # Manually zero the gradients after updating weights
            w[-1].grad.zero_()
            
        #    data_tsne_rp2.append(z2.cpu().data.numpy())
        #    data_tsne_rp1.append(z1.cpu().data.numpy())
        #    data_tsne_label.append(target.argmax(dim=1, keepdim=True).cpu().data.numpy())
        

        if i_batch %100 ==0:
            costs.append(cost)
            print(i_batch)
            print('cost',cost)
            print('entr',entropy)
            print('inf',information)
            data_tsne_label.append(target.argmax(dim=1, keepdim=True).cpu().data.numpy())
            torch.save({
            'w': w,
            'z': z,
            'data_tsne_label':target.argmax(dim=1, keepdim=True).cpu().data.numpy()
            ,'costs':costs
            #'data_tsne_rp2':data_tsne_rp2,
            #'data_tsne_rp1':data_tsne_rp1
                
            }, PATH)
            
            data_tsne_label=[]
            #data_tsne_rp1=[]
            #data_tsne_rp2=[]

            #for j,zz in enumerate(z2):
                #print(j,zz)
                #print(j,target[j])
            
plt.plot(costs)
plt.ylabel('cost2')
plt.xlabel('epochs (per 1)')
plt.title("Learning rate = " + str(learning_rate))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['dtype', 'entropy']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# 0
# cost tensor(0.9207, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3657, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4449, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9199, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3050, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3851, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.9273, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3354, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4081, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.9154, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3570, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4415, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9226, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3669, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4443, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.9487, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3603, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4116, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.9351, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3465, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4114, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9407, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3417, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4009, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.9304, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3457, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4153, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.9445, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3596, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4151, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9223, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3297, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4074, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.8955, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3109, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4154, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.9505, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3525, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4020, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.8866, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.2678, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3812, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.9570, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3563, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3994, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.9049, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3096, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4048, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9274, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3348, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4074, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.8924, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.2824, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3900, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.9000, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3189, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4189, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9351, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3580, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4229, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.9481, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.4188, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4707, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.9154, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3444, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4290, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9240, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3732, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4492, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.8809, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.2851, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4042, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.9059, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3507, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4448, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.8769, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.2812, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4043, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.9080, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3216, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4136, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.8677, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.2501, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3824, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9151, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3200, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4049, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.8491, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.2249, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3758, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.9116, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3276, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4160, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9007, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3208, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.4201, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.8810, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.2669, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3859, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.8703, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.2490, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3787, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9438, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3270, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3832, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.9355, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3295, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3940, device='cuda:0', grad_fn=<MulBackward0>)
# 0
# cost tensor(0.8765, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.2683, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3919, device='cuda:0', grad_fn=<MulBackward0>)
# 100
# cost tensor(0.9289, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.3234, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3945, device='cuda:0', grad_fn=<MulBackward0>)
# 200
# cost tensor(0.8938, device='cuda:0', grad_fn=<SubBackward0>)
# entr tensor(1.2735, device='cuda:0', grad_fn=<MulBackward0>)
# inf tensor(0.3797, device='cuda:0', grad_fn=<MulBackward0>)

# %%
cost tensor(0.8703, device='cuda:0', grad_fn=<SubBackward0>)
entr tensor(1.2490, device='cuda:0', grad_fn=<MulBackward0>)
inf tensor(0.3787, device='cuda:0', grad_fn=<MulBackward0>)
100
cost tensor(0.9438, device='cuda:0', grad_fn=<SubBackward0>)
entr tensor(1.3270, device='cuda:0', grad_fn=<MulBackward0>)
inf tensor(0.3832, device='cuda:0', grad_fn=<MulBackward0>)
200
cost tensor(0.9355, device='cuda:0', grad_fn=<SubBackward0>)
entr tensor(1.3295, device='cuda:0', grad_fn=<MulBackward0>)
inf tensor(0.3940, device='cuda:0', grad_fn=<MulBackward0>)
0
cost tensor(0.8765, device='cuda:0', grad_fn=<SubBackward0>)
entr tensor(1.2683, device='cuda:0', grad_fn=<MulBackward0>)
inf tensor(0.3919, device='cuda:0', grad_fn=<MulBackward0>)
100
cost tensor(0.9289, device='cuda:0', grad_fn=<SubBackward0>)
entr tensor(1.3234, device='cuda:0', grad_fn=<MulBackward0>)
inf tensor(0.3945, device='cuda:0', grad_fn=<MulBackward0>)
200
cost tensor(0.8938, device='cuda:0', grad_fn=<SubBackward0>)
entr tensor(1.2735, device='cuda:0', grad_fn=<MulBackward0>)
inf tensor(0.3797, device='cuda:0', grad_fn=<MulBackward0>)
